# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
r_cols = ["user_id", "movie_id", "rating"]
ratings = pd.read_csv("./data/movie_recommender/u.data", sep="\t", names=r_cols, usecols=range(3), encoding="ISO-8859-1")

m_cols = ["movie_id", "title"]
movies = pd.read_csv("./data/movie_recommender/u.item", sep="|", names=m_cols, usecols=range(2), encoding="ISO-8859-1")

ratings = pd.merge(movies, ratings)

# %%
ratings
# Out:
#         movie_id                                      title  user_id  rating
# 0              1                           Toy Story (1995)      308       4
# 1              1                           Toy Story (1995)      287       5
# 2              1                           Toy Story (1995)      148       4
# 3              1                           Toy Story (1995)      280       4
# 4              1                           Toy Story (1995)       66       3
# ...          ...                                        ...      ...     ...
# 99998       1678                          Mat' i syn (1997)      863       1
# 99999       1679                           B. Monkey (1998)      863       3
# 100000      1680                       Sliding Doors (1998)      863       2
# 100001      1681                        You So Crazy (1994)      896       3
# 100002      1682  Scream of Stone (Schrei aus Stein) (1991)      916       3
#
# [100003 rows x 4 columns]

# %%
movieRatings = ratings.pivot_table(index=["user_id"], columns=["title"], values="rating")
movieRatings
# Out:
# title    'Til There Was You (1997)  1-900 (1994)  101 Dalmatians (1996)  \
# user_id
# 0                              NaN           NaN                    NaN
# 1                              NaN           NaN                    2.0
# 2                              NaN           NaN                    NaN
# 3                              NaN           NaN                    NaN
# 4                              NaN           NaN                    NaN
# ...                            ...           ...                    ...
# 939                            NaN           NaN                    NaN
# 940                            NaN           NaN                    NaN
# 941                            NaN           NaN                    NaN
# 942                            NaN           NaN                    NaN
# 943                            NaN           NaN                    NaN
#
# title    12 Angry Men (1957)  187 (1997)  2 Days in the Valley (1996)  \
# user_id
# 0                        NaN         NaN                          NaN
# 1                        5.0         NaN                          NaN
# 2                        NaN         NaN                          NaN
# 3                        NaN         2.0                          NaN
# 4                        NaN         NaN                          NaN
# ...                      ...         ...                          ...
# 939                      NaN         NaN                          NaN
# 940                      NaN         NaN                          NaN
# 941                      NaN         NaN                          NaN
# 942                      NaN         NaN                          NaN
# 943                      NaN         NaN                          2.0
#
# title    20,000 Leagues Under the Sea (1954)  2001: A Space Odyssey (1968)  \
# user_id
# 0                                        NaN                           NaN
# 1                                        3.0                           4.0
# 2                                        NaN                           NaN
# 3                                        NaN                           NaN
# 4                                        NaN                           NaN
# ...                                      ...                           ...
# 939                                      NaN                           NaN
# 940                                      NaN                           NaN
# 941                                      NaN                           NaN
# 942                                      NaN                           3.0
# 943                                      NaN                           NaN
#
# title    3 Ninjas: High Noon At Mega Mountain (1998)  39 Steps, The (1935)  \
# user_id
# 0                                                NaN                   NaN
# 1                                                NaN                   NaN
# 2                                                1.0                   NaN
# 3                                                NaN                   NaN
# 4                                                NaN                   NaN
# ...                                              ...                   ...
# 939                                              NaN                   NaN
# 940                                              NaN                   NaN
# 941                                              NaN                   NaN
# 942                                              NaN                   3.0
# 943                                              NaN                   NaN
#
# title    ...  Yankee Zulu (1994)  Year of the Horse (1997)  \
# user_id  ...
# 0        ...                 NaN                       NaN
# 1        ...                 NaN                       NaN
# 2        ...                 NaN                       NaN
# 3        ...                 NaN                       NaN
# 4        ...                 NaN                       NaN
# ...      ...                 ...                       ...
# 939      ...                 NaN                       NaN
# 940      ...                 NaN                       NaN
# 941      ...                 NaN                       NaN
# 942      ...                 NaN                       NaN
# 943      ...                 NaN                       NaN
#
# title    You So Crazy (1994)  Young Frankenstein (1974)  Young Guns (1988)  \
# user_id
# 0                        NaN                        NaN                NaN
# 1                        NaN                        5.0                3.0
# 2                        NaN                        NaN                NaN
# 3                        NaN                        NaN                NaN
# 4                        NaN                        NaN                NaN
# ...                      ...                        ...                ...
# 939                      NaN                        NaN                NaN
# 940                      NaN                        NaN                NaN
# 941                      NaN                        NaN                NaN
# 942                      NaN                        NaN                NaN
# 943                      NaN                        NaN                4.0
#
# title    Young Guns II (1990)  Young Poisoner's Handbook, The (1995)  \
# user_id
# 0                         NaN                                    NaN
# 1                         NaN                                    NaN
# 2                         NaN                                    NaN
# 3                         NaN                                    NaN
# 4                         NaN                                    NaN
# ...                       ...                                    ...
# 939                       NaN                                    NaN
# 940                       NaN                                    NaN
# 941                       NaN                                    NaN
# 942                       NaN                                    NaN
# 943                       3.0                                    NaN
#
# title    Zeus and Roxanne (1997)  unknown  Á köldum klaka (Cold Fever) (1994)
# user_id
# 0                            NaN      NaN                                 NaN
# 1                            NaN      4.0                                 NaN
# 2                            NaN      NaN                                 NaN
# 3                            NaN      NaN                                 NaN
# 4                            NaN      NaN                                 NaN
# ...                          ...      ...                                 ...
# 939                          NaN      NaN                                 NaN
# 940                          NaN      NaN                                 NaN
# 941                          NaN      NaN                                 NaN
# 942                          NaN      NaN                                 NaN
# 943                          NaN      NaN                                 NaN
#
# [944 rows x 1664 columns]

# %%
# correlate every movie to Start Wars (1977)
similarMovies = movieRatings.corrwith(movieRatings["Star Wars (1977)"])
similarMovies = similarMovies.dropna()
df = pd.DataFrame(similarMovies)
df
# Out:
# C:\Users\paulw\anaconda3\lib\site-packages\numpy\lib\function_base.py:2526: RuntimeWarning: Degrees of freedom <= 0 for slice
#   c = cov(x, y, rowvar)
# C:\Users\paulw\anaconda3\lib\site-packages\numpy\lib\function_base.py:2455: RuntimeWarning: divide by zero encountered in true_divide
#   c *= np.true_divide(1, fact)
#                                               0
# title
# 'Til There Was You (1997)              0.872872
# 1-900 (1994)                          -0.645497
# 101 Dalmatians (1996)                  0.211132
# 12 Angry Men (1957)                    0.184289
# 187 (1997)                             0.027398
# ...                                         ...
# Young Guns (1988)                      0.186377
# Young Guns II (1990)                   0.228615
# Young Poisoner's Handbook, The (1995) -0.007374
# Zeus and Roxanne (1997)                0.818182
# unknown                                0.723123
#
# [1410 rows x 1 columns]

# %%
# not filtered by size
similarMovies.sort_values(ascending=False)
# Out:
# title
# No Escape (1994)                          1.0
# Man of the Year (1995)                    1.0
# Hollow Reed (1996)                        1.0
# Commandments (1997)                       1.0
# Cosi (1996)                               1.0
#                                          ...
# Theodore Rex (1995)                      -1.0
# I Like It Like That (1994)               -1.0
# Two Deaths (1995)                        -1.0
# Roseanna's Grave (For Roseanna) (1997)   -1.0
# Frankie Starlight (1995)                 -1.0
# Length: 1410, dtype: float64

# %%
movieStats = ratings.groupby("title").agg({"rating": [np.size, np.mean]})
movieStats
# Out:
#                                       rating
#                                         size      mean
# title
# 'Til There Was You (1997)                  9  2.333333
# 1-900 (1994)                               5  2.600000
# 101 Dalmatians (1996)                    109  2.908257
# 12 Angry Men (1957)                      125  4.344000
# 187 (1997)                                41  3.024390
# ...                                      ...       ...
# Young Guns II (1990)                      44  2.772727
# Young Poisoner's Handbook, The (1995)     41  3.341463
# Zeus and Roxanne (1997)                    6  2.166667
# unknown                                    9  3.444444
# Á köldum klaka (Cold Fever) (1994)         1  3.000000
#
# [1664 rows x 2 columns]

# %%
popularMovies = movieStats["rating"]["size"] >= 100

# %%
movieStats[popularMovies].sort_values([("rating", "mean")], ascending=False)
# Out:
#                                  rating
#                                    size      mean
# title
# Close Shave, A (1995)               112  4.491071
# Schindler's List (1993)             298  4.466443
# Wrong Trousers, The (1993)          118  4.466102
# Casablanca (1942)                   243  4.456790
# Shawshank Redemption, The (1994)    283  4.445230
# ...                                 ...       ...
# Spawn (1997)                        143  2.615385
# Event Horizon (1997)                127  2.574803
# Crash (1996)                        128  2.546875
# Jungle2Jungle (1997)                132  2.439394
# Cable Guy, The (1996)               106  2.339623
#
# [338 rows x 2 columns]

# %%
df = movieStats[popularMovies].join(pd.DataFrame(similarMovies, columns=["similarity"]))
# Out:
# C:\Users\paulw\anaconda3\lib\site-packages\pandas\core\reshape\merge.py:618: UserWarning: merging between different levels can give an unintended result (2 levels on the left, 1 on the right)
#   warnings.warn(msg, UserWarning)

# %%
df.sort_values(["similarity"], ascending=False)[:15]
# Out:
#                                                     (rating, size)  \
# title
# Star Wars (1977)                                               584
# Empire Strikes Back, The (1980)                                368
# Return of the Jedi (1983)                                      507
# Raiders of the Lost Ark (1981)                                 420
# Austin Powers: International Man of Mystery (1997)             130
# Sting, The (1973)                                              241
# Indiana Jones and the Last Crusade (1989)                      331
# Pinocchio (1940)                                               101
# Frighteners, The (1996)                                        115
# L.A. Confidential (1997)                                       297
# Wag the Dog (1997)                                             137
# Dumbo (1941)                                                   123
# Bridge on the River Kwai, The (1957)                           165
# Philadelphia Story, The (1940)                                 104
# Miracle on 34th Street (1994)                                  101
#
#                                                     (rating, mean)  similarity
# title
# Star Wars (1977)                                          4.359589    1.000000
# Empire Strikes Back, The (1980)                           4.206522    0.748353
# Return of the Jedi (1983)                                 4.007890    0.672556
# Raiders of the Lost Ark (1981)                            4.252381    0.536117
# Austin Powers: International Man of Mystery (1997)        3.246154    0.377433
# Sting, The (1973)                                         4.058091    0.367538
# Indiana Jones and the Last Crusade (1989)                 3.930514    0.350107
# Pinocchio (1940)                                          3.673267    0.347868
# Frighteners, The (1996)                                   3.234783    0.332729
# L.A. Confidential (1997)                                  4.161616    0.319065
# Wag the Dog (1997)                                        3.510949    0.318645
# Dumbo (1941)                                              3.495935    0.317656
# Bridge on the River Kwai, The (1957)                      4.175758    0.316580
# Philadelphia Story, The (1940)                            4.115385    0.314272
# Miracle on 34th Street (1994)                             3.722772    0.310921

# %%
corrMatrix = movieRatings.corr(method="pearson", min_periods=100)
corrMatrix.dropna(how="all").dropna(axis=1, how="all")
# Out:
# title                                         101 Dalmatians (1996)  \
# title
# 101 Dalmatians (1996)                                           1.0
# 12 Angry Men (1957)                                             NaN
# 2001: A Space Odyssey (1968)                                    NaN
# Absolute Power (1997)                                           NaN
# Abyss, The (1989)                                               NaN
# ...                                                             ...
# Willy Wonka and the Chocolate Factory (1971)                    NaN
# Wizard of Oz, The (1939)                                        NaN
# Wrong Trousers, The (1993)                                      NaN
# Young Frankenstein (1974)                                       NaN
# Young Guns (1988)                                               NaN
#
# title                                         12 Angry Men (1957)  \
# title
# 101 Dalmatians (1996)                                         NaN
# 12 Angry Men (1957)                                           1.0
# 2001: A Space Odyssey (1968)                                  NaN
# Absolute Power (1997)                                         NaN
# Abyss, The (1989)                                             NaN
# ...                                                           ...
# Willy Wonka and the Chocolate Factory (1971)                  NaN
# Wizard of Oz, The (1939)                                      NaN
# Wrong Trousers, The (1993)                                    NaN
# Young Frankenstein (1974)                                     NaN
# Young Guns (1988)                                             NaN
#
# title                                         2001: A Space Odyssey (1968)  \
# title
# 101 Dalmatians (1996)                                                  NaN
# 12 Angry Men (1957)                                                    NaN
# 2001: A Space Odyssey (1968)                                      1.000000
# Absolute Power (1997)                                                  NaN
# Abyss, The (1989)                                                      NaN
# ...                                                                    ...
# Willy Wonka and the Chocolate Factory (1971)                      0.147293
# Wizard of Oz, The (1939)                                          0.236830
# Wrong Trousers, The (1993)                                             NaN
# Young Frankenstein (1974)                                        -0.001307
# Young Guns (1988)                                                      NaN
#
# title                                         Absolute Power (1997)  \
# title
# 101 Dalmatians (1996)                                           NaN
# 12 Angry Men (1957)                                             NaN
# 2001: A Space Odyssey (1968)                                    NaN
# Absolute Power (1997)                                           1.0
# Abyss, The (1989)                                               NaN
# ...                                                             ...
# Willy Wonka and the Chocolate Factory (1971)                    NaN
# Wizard of Oz, The (1939)                                        NaN
# Wrong Trousers, The (1993)                                      NaN
# Young Frankenstein (1974)                                       NaN
# Young Guns (1988)                                               NaN
#
# title                                         Abyss, The (1989)  \
# title
# 101 Dalmatians (1996)                                       NaN
# 12 Angry Men (1957)                                         NaN
# 2001: A Space Odyssey (1968)                                NaN
# Absolute Power (1997)                                       NaN
# Abyss, The (1989)                                           1.0
# ...                                                         ...
# Willy Wonka and the Chocolate Factory (1971)                NaN
# Wizard of Oz, The (1939)                                    NaN
# Wrong Trousers, The (1993)                                  NaN
# Young Frankenstein (1974)                                   NaN
# Young Guns (1988)                                           NaN
#
# title                                         Ace Ventura: Pet Detective (1994)  \
# title
# 101 Dalmatians (1996)                                                       NaN
# 12 Angry Men (1957)                                                         NaN
# 2001: A Space Odyssey (1968)                                                NaN
# Absolute Power (1997)                                                       NaN
# Abyss, The (1989)                                                           NaN
# ...                                                                         ...
# Willy Wonka and the Chocolate Factory (1971)                                NaN
# Wizard of Oz, The (1939)                                                    NaN
# Wrong Trousers, The (1993)                                                  NaN
# Young Frankenstein (1974)                                                   NaN
# Young Guns (1988)                                                           NaN
#
# title                                         Adventures of Priscilla, Queen of the Desert, The (1994)  \
# title
# 101 Dalmatians (1996)                                                                       NaN
# 12 Angry Men (1957)                                                                         NaN
# 2001: A Space Odyssey (1968)                                                                NaN
# Absolute Power (1997)                                                                       NaN
# Abyss, The (1989)                                                                           NaN
# ...                                                                                         ...
# Willy Wonka and the Chocolate Factory (1971)                                                NaN
# Wizard of Oz, The (1939)                                                                    NaN
# Wrong Trousers, The (1993)                                                                  NaN
# Young Frankenstein (1974)                                                                   NaN
# Young Guns (1988)                                                                           NaN
#
# title                                         African Queen, The (1951)  \
# title
# 101 Dalmatians (1996)                                               NaN
# 12 Angry Men (1957)                                                 NaN
# 2001: A Space Odyssey (1968)                                   0.152433
# Absolute Power (1997)                                               NaN
# Abyss, The (1989)                                                   NaN
# ...                                                                 ...
# Willy Wonka and the Chocolate Factory (1971)                        NaN
# Wizard of Oz, The (1939)                                       0.508389
# Wrong Trousers, The (1993)                                          NaN
# Young Frankenstein (1974)                                           NaN
# Young Guns (1988)                                                   NaN
#
# title                                         Air Force One (1997)  \
# title
# 101 Dalmatians (1996)                                          NaN
# 12 Angry Men (1957)                                            NaN
# 2001: A Space Odyssey (1968)                                   NaN
# Absolute Power (1997)                                          NaN
# Abyss, The (1989)                                              NaN
# ...                                                            ...
# Willy Wonka and the Chocolate Factory (1971)             -0.132312
# Wizard of Oz, The (1939)                                       NaN
# Wrong Trousers, The (1993)                                     NaN
# Young Frankenstein (1974)                                      NaN
# Young Guns (1988)                                              NaN
#
# title                                         Aladdin (1992)  ...  \
# title                                                         ...
# 101 Dalmatians (1996)                                    NaN  ...
# 12 Angry Men (1957)                                      NaN  ...
# 2001: A Space Odyssey (1968)                       -0.067992  ...
# Absolute Power (1997)                                    NaN  ...
# Abyss, The (1989)                                        NaN  ...
# ...                                                      ...  ...
# Willy Wonka and the Chocolate Factory (1971)        0.159210  ...
# Wizard of Oz, The (1939)                            0.300988  ...
# Wrong Trousers, The (1993)                               NaN  ...
# Young Frankenstein (1974)                           0.037317  ...
# Young Guns (1988)                                        NaN  ...
#
# title                                         Welcome to the Dollhouse (1995)  \
# title
# 101 Dalmatians (1996)                                                     NaN
# 12 Angry Men (1957)                                                       NaN
# 2001: A Space Odyssey (1968)                                              NaN
# Absolute Power (1997)                                                     NaN
# Abyss, The (1989)                                                         NaN
# ...                                                                       ...
# Willy Wonka and the Chocolate Factory (1971)                              NaN
# Wizard of Oz, The (1939)                                                  NaN
# Wrong Trousers, The (1993)                                                NaN
# Young Frankenstein (1974)                                                 NaN
# Young Guns (1988)                                                         NaN
#
# title                                         What's Eating Gilbert Grape (1993)  \
# title
# 101 Dalmatians (1996)                                                        NaN
# 12 Angry Men (1957)                                                          NaN
# 2001: A Space Odyssey (1968)                                                 NaN
# Absolute Power (1997)                                                        NaN
# Abyss, The (1989)                                                            NaN
# ...                                                                          ...
# Willy Wonka and the Chocolate Factory (1971)                                 NaN
# Wizard of Oz, The (1939)                                                     NaN
# Wrong Trousers, The (1993)                                                   NaN
# Young Frankenstein (1974)                                                    NaN
# Young Guns (1988)                                                            NaN
#
# title                                         When Harry Met Sally... (1989)  \
# title
# 101 Dalmatians (1996)                                                    NaN
# 12 Angry Men (1957)                                                      NaN
# 2001: A Space Odyssey (1968)                                        0.023712
# Absolute Power (1997)                                                    NaN
# Abyss, The (1989)                                                        NaN
# ...                                                                      ...
# Willy Wonka and the Chocolate Factory (1971)                        0.096966
# Wizard of Oz, The (1939)                                            0.239380
# Wrong Trousers, The (1993)                                               NaN
# Young Frankenstein (1974)                                           0.153234
# Young Guns (1988)                                                        NaN
#
# title                                         While You Were Sleeping (1995)  \
# title
# 101 Dalmatians (1996)                                                    NaN
# 12 Angry Men (1957)                                                      NaN
# 2001: A Space Odyssey (1968)                                             NaN
# Absolute Power (1997)                                                    NaN
# Abyss, The (1989)                                                        NaN
# ...                                                                      ...
# Willy Wonka and the Chocolate Factory (1971)                             NaN
# Wizard of Oz, The (1939)                                                 NaN
# Wrong Trousers, The (1993)                                               NaN
# Young Frankenstein (1974)                                                NaN
# Young Guns (1988)                                                        NaN
#
# title                                         William Shakespeare's Romeo and Juliet (1996)  \
# title
# 101 Dalmatians (1996)                                                                   NaN
# 12 Angry Men (1957)                                                                     NaN
# 2001: A Space Odyssey (1968)                                                            NaN
# Absolute Power (1997)                                                                   NaN
# Abyss, The (1989)                                                                       NaN
# ...                                                                                     ...
# Willy Wonka and the Chocolate Factory (1971)                                            NaN
# Wizard of Oz, The (1939)                                                                NaN
# Wrong Trousers, The (1993)                                                              NaN
# Young Frankenstein (1974)                                                               NaN
# Young Guns (1988)                                                                       NaN
#
# title                                         Willy Wonka and the Chocolate Factory (1971)  \
# title
# 101 Dalmatians (1996)                                                                  NaN
# 12 Angry Men (1957)                                                                    NaN
# 2001: A Space Odyssey (1968)                                                      0.147293
# Absolute Power (1997)                                                                  NaN
# Abyss, The (1989)                                                                      NaN
# ...                                                                                    ...
# Willy Wonka and the Chocolate Factory (1971)                                      1.000000
# Wizard of Oz, The (1939)                                                          0.294893
# Wrong Trousers, The (1993)                                                             NaN
# Young Frankenstein (1974)                                                         0.291210
# Young Guns (1988)                                                                      NaN
#
# title                                         Wizard of Oz, The (1939)  \
# title
# 101 Dalmatians (1996)                                              NaN
# 12 Angry Men (1957)                                                NaN
# 2001: A Space Odyssey (1968)                                  0.236830
# Absolute Power (1997)                                              NaN
# Abyss, The (1989)                                                  NaN
# ...                                                                ...
# Willy Wonka and the Chocolate Factory (1971)                  0.294893
# Wizard of Oz, The (1939)                                      1.000000
# Wrong Trousers, The (1993)                                         NaN
# Young Frankenstein (1974)                                     0.244063
# Young Guns (1988)                                                  NaN
#
# title                                         Wrong Trousers, The (1993)  \
# title
# 101 Dalmatians (1996)                                                NaN
# 12 Angry Men (1957)                                                  NaN
# 2001: A Space Odyssey (1968)                                         NaN
# Absolute Power (1997)                                                NaN
# Abyss, The (1989)                                                    NaN
# ...                                                                  ...
# Willy Wonka and the Chocolate Factory (1971)                         NaN
# Wizard of Oz, The (1939)                                             NaN
# Wrong Trousers, The (1993)                                           1.0
# Young Frankenstein (1974)                                            NaN
# Young Guns (1988)                                                    NaN
#
# title                                         Young Frankenstein (1974)  \
# title
# 101 Dalmatians (1996)                                               NaN
# 12 Angry Men (1957)                                                 NaN
# 2001: A Space Odyssey (1968)                                  -0.001307
# Absolute Power (1997)                                               NaN
# Abyss, The (1989)                                                   NaN
# ...                                                                 ...
# Willy Wonka and the Chocolate Factory (1971)                   0.291210
# Wizard of Oz, The (1939)                                       0.244063
# Wrong Trousers, The (1993)                                          NaN
# Young Frankenstein (1974)                                      1.000000
# Young Guns (1988)                                                   NaN
#
# title                                         Young Guns (1988)
# title
# 101 Dalmatians (1996)                                       NaN
# 12 Angry Men (1957)                                         NaN
# 2001: A Space Odyssey (1968)                                NaN
# Absolute Power (1997)                                       NaN
# Abyss, The (1989)                                           NaN
# ...                                                         ...
# Willy Wonka and the Chocolate Factory (1971)                NaN
# Wizard of Oz, The (1939)                                    NaN
# Wrong Trousers, The (1993)                                  NaN
# Young Frankenstein (1974)                                   NaN
# Young Guns (1988)                                           1.0
#
# [337 rows x 337 columns]

# %%
firstRatings = movieRatings.iloc[0].dropna(0)
firstRatings
# Out:
# title
# Empire Strikes Back, The (1980)    5.0
# Gone with the Wind (1939)          1.0
# Star Wars (1977)                   5.0
# Name: 0, dtype: float64

# %%
simCandidates = pd.Series(dtype="object")

for i in range(0 ,len(firstRatings.index)):
    print("Adding sims for " + firstRatings.index[i])
    sims = corrMatrix[firstRatings.index[i]].dropna()
    # scale the movies rating
    sims = sims.map(lambda x: x * firstRatings[i])
    simCandidates = simCandidates.append(sims)
    
simCandidates.sort_values(inplace=True, ascending=False)
simCandidates
# Out:
# Adding sims for Empire Strikes Back, The (1980)
# Adding sims for Gone with the Wind (1939)
# Adding sims for Star Wars (1977)
# Empire Strikes Back, The (1980)    5.000000
# Star Wars (1977)                   5.000000
# Empire Strikes Back, The (1980)    3.741763
# Star Wars (1977)                   3.741763
# Return of the Jedi (1983)          3.606146
#                                      ...
# Real Genius (1985)                -0.480527
# Annie Hall (1977)                 -0.500600
# Remains of the Day, The (1993)    -0.560337
# Piano, The (1993)                 -0.751857
# First Wives Club, The (1996)      -0.972480
# Length: 515, dtype: float64

# %%
simCandidates = simCandidates.groupby(simCandidates.index).sum()

# %%
simCandidates.sort_values(inplace=True, ascending=False)

# %%
simCandidates

# %%
filteredSims = simCandidates.drop(firstRatings.index)
filteredSims
# Out:
# Return of the Jedi (1983)                    7.178172
# Raiders of the Lost Ark (1981)               5.519700
# Indiana Jones and the Last Crusade (1989)    3.488028
# Bridge on the River Kwai, The (1957)         3.366616
# Back to the Future (1985)                    3.357941
#                                                ...
# Annie Hall (1977)                           -0.511775
# Real Genius (1985)                          -0.552871
# Remains of the Day, The (1993)              -0.560337
# This Is Spinal Tap (1984)                   -0.636474
# First Wives Club, The (1996)                -0.972480
# Length: 265, dtype: float64
